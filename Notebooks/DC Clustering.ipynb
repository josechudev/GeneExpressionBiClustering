# %% [markdown]
# # Clustering

# %%
import gc
import pandas as pd
import glob
import sklearn
import numpy as np

# %%
dcFiles=glob.glob("../data/Dc/*")
dcFiles
# Out:
# ['../data/Dc/Jnk.csv',
#  '../data/Dc/IRF4.csv',
#  '../data/Dc/LEF1.csv',
#  '../data/Dc/Ikk2.csv',
#  '../data/Dc/CTNNB1.csv',
#  '../data/Dc/Erk.csv',
#  '../data/Dc/MYC.csv']

# %%
trainIndexFiles=glob.glob("../Train/*")

# %%
trainIndexFiles
# Out:
# ['../Train/LEF1.index.csv',
#  '../Train/MYC.index.csv',
#  '../Train/IRF4.index.csv',
#  '../Train/Jnk.index.csv',
#  '../Train/Ikk2.index.csv',
#  '../Train/Erk.index.csv',
#  '../Train/CTNNB1.index.csv']

# %%
frames = list()
for f in trainIndexFiles:
    indices = pd.read_csv(f,sep=";")
    indexList=list(indices['0'])
    protein = f.split("/")[-1].split(".")[0]
    fpath = '..data/Dc/'+f.split("/")[-1].split(".")[0]+".csv"
    dcRead = pd.read_csv(fpath,sep=";")
    dcPartialTrain=dcRead[dcRead.columns[5:]].loc[indexList].copy()
    dcPartialTrain.insert(0,column='Protein',value =protein )
    del dcRead
    gc.collect()
    frames.append(dcPartialTrain)

# %%
dcTrain = pd.concat(frames)

# %%
dcTrain.to_csv("../FullTrain/FullTrainDC/FullTrainDC.csv")

# %%
dcTrain.head()
# Out:
#      Protein  X0min_neg_effect-X0min_neg_cause  X15min_effect-X0min_neg_cause  \
# 1530    LEF1                          1.023241                       0.724441
# 1531    LEF1                          0.169366                       0.093080
# 1532    LEF1                          1.887236                       0.981507
# 1533    LEF1                          0.237701                      -0.071842
# 1535    LEF1                          0.757642                       0.409183
#
#       X15min_effect-X15min_cause  X30min_effect-X0min_neg_cause  \
# 1530                    0.818558                       0.563618
# 1531                    0.621927                       0.102329
# 1532                    2.324589                       0.764263
# 1533                    0.166615                       0.123891
# 1535                    0.489564                      -0.257325
#
#       X30min_effect-X15min_cause  X30min_effect-X30min_cause  \
# 1530                    0.484836                    0.672051
# 1531                    0.108679                    0.166695
# 1532                    0.324520                    1.247644
# 1533                   -0.070192                    0.429748
# 1535                   -0.228940                    0.444693
#
#       X90min_effect-X0min_neg_cause  X90min_effect-X15min_cause  \
# 1530                      -0.033114                   -0.013766
# 1531                       0.022466                    0.021222
# 1532                      -0.241862                   -0.431564
# 1533                      -0.033902                    0.010897
# 1535                       0.024037                    0.013811
#
#       X90min_effect-X30min_cause              ...               \
# 1530                    0.068516              ...
# 1531                    0.052001              ...
# 1532                   -0.149245              ...
# 1533                   -0.006371              ...
# 1535                    0.029758              ...
#
#       X240min_effect-X240min_cause  X360min_effect-X0min_neg_cause  \
# 1530                      1.759207                        0.168689
# 1531                      0.422824                       -0.093931
# 1532                      0.462031                        0.728134
# 1533                      0.559448                       -0.021912
# 1535                      1.067780                        0.156884
#
#       X360min_effect-X15min_cause  X360min_effect-X30min_cause  \
# 1530                     0.138546                     0.072377
# 1531                     0.017554                    -0.044028
# 1532                     0.877128                     0.352315
# 1533                     0.067405                    -0.021690
# 1535                     0.128128                    -0.064193
#
#       X360min_effect-X90min_cause  X360min_effect-X120min_cause  \
# 1530                    -0.208468                      0.002047
# 1531                    -0.024721                     -0.009345
# 1532                    -0.127248                     -0.097222
# 1533                     0.000144                      0.007487
# 1535                     0.042174                      0.131908
#
#       X360min_effect-X180min_cause  X360min_effect-X210min_cause  \
# 1530                     -0.033598                      0.196686
# 1531                      0.050461                     -0.073455
# 1532                     -0.054824                      0.538076
# 1533                      0.128203                     -0.146404
# 1535                      0.014193                      0.045039
#
#       X360min_effect-X240min_cause  X360min_effect-X360min_cause
# 1530                     -0.146813                      0.336667
# 1531                     -0.042127                      0.806875
# 1532                      0.111132                      1.637100
# 1533                      0.111754                      0.439802
# 1535                      0.037291                      0.423915
#
# [5 rows x 46 columns]

# %%
dcTrain.describe()
# Out:
#        X0min_neg_effect-X0min_neg_cause  X15min_effect-X0min_neg_cause  \
# count                      15998.000000                   15998.000000
# mean                           1.123929                       0.160854
# std                            1.381386                       0.697635
# min                            0.005955                      -2.873166
# 25%                            0.288136                      -0.092662
# 50%                            0.652447                       0.015501
# 75%                            1.410917                       0.277699
# max                           15.983560                       5.559741
#
#        X15min_effect-X15min_cause  X30min_effect-X0min_neg_cause  \
# count                15998.000000                   15998.000000
# mean                     1.645680                       0.153058
# std                      2.480283                       0.574321
# min                      0.003743                      -3.261047
# 25%                      0.251017                      -0.061253
# 50%                      0.747891                       0.028118
# 75%                      1.883361                       0.237325
# max                     23.125571                       4.308566
#
#        X30min_effect-X15min_cause  X30min_effect-X30min_cause  \
# count                15998.000000                15998.000000
# mean                     0.101716                    0.818870
# std                      0.588600                    0.944017
# min                     -3.345677                    0.010287
# 25%                     -0.070234                    0.245224
# 50%                      0.022113                    0.494980
# 75%                      0.190688                    1.017800
# max                      5.087045                   10.578990
#
#        X90min_effect-X0min_neg_cause  X90min_effect-X15min_cause  \
# count                   15998.000000                15998.000000
# mean                        0.011536                    0.092502
# std                         0.337735                    0.364203
# min                        -2.446163                   -3.243441
# 25%                        -0.099733                   -0.061802
# 50%                         0.002810                    0.008058
# 75%                         0.124301                    0.196168
# max                         3.851405                    2.022791
#
#        X90min_effect-X30min_cause  X90min_effect-X90min_cause  \
# count                15998.000000                15998.000000
# mean                     0.034155                    0.746412
# std                      0.267684                    0.783058
# min                     -1.514655                    0.010793
# 25%                     -0.084631                    0.282155
# 50%                      0.007538                    0.493237
# 75%                      0.118070                    0.913296
# max                      2.045412                    9.609743
#
#                    ...               X240min_effect-X240min_cause  \
# count              ...                               15998.000000
# mean               ...                                   0.962176
# std                ...                                   1.552828
# min                ...                                   0.008611
# 25%                ...                                   0.230529
# 50%                ...                                   0.502017
# 75%                ...                                   1.068317
# max                ...                                  28.497410
#
#        X360min_effect-X0min_neg_cause  X360min_effect-X15min_cause  \
# count                    15998.000000                 15998.000000
# mean                         0.081797                     0.064953
# std                          0.375962                     0.540119
# min                         -2.259021                    -4.522357
# 25%                         -0.088965                    -0.074280
# 50%                          0.007391                     0.008589
# 75%                          0.232870                     0.178840
# max                          2.115524                     7.625887
#
#        X360min_effect-X30min_cause  X360min_effect-X90min_cause  \
# count                 15998.000000                 15998.000000
# mean                      0.081970                     0.021553
# std                       0.338621                     0.298737
# min                      -2.190252                    -1.502448
# 25%                      -0.052912                    -0.098582
# 50%                       0.006277                     0.008474
# 75%                       0.147552                     0.140150
# max                       2.108503                     1.868167
#
#        X360min_effect-X120min_cause  X360min_effect-X180min_cause  \
# count                  15998.000000                  15998.000000
# mean                       0.011708                      0.014357
# std                        0.274958                      0.249014
# min                       -2.094498                     -1.516737
# 25%                       -0.071642                     -0.073431
# 50%                        0.002149                      0.006571
# 75%                        0.088821                      0.100314
# max                        3.420092                      1.771488
#
#        X360min_effect-X210min_cause  X360min_effect-X240min_cause  \
# count                  15998.000000                  15998.000000
# mean                      -0.003287                     -0.002581
# std                        0.538287                      0.290573
# min                       -4.338766                     -2.895888
# 25%                       -0.107294                     -0.105230
# 50%                        0.001314                      0.001720
# 75%                        0.113457                      0.104822
# max                        6.950149                      2.029939
#
#        X360min_effect-X360min_cause
# count                  15998.000000
# mean                       1.248324
# std                        1.664007
# min                        0.008348
# 25%                        0.288657
# 50%                        0.656951
# 75%                        1.481852
# max                       16.036858
#
# [8 rows x 45 columns]

# %%
lstn_clusters=range(2,30)

# %%
import time
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score

# %%
file = open('../ClusteringOutputs/DC_Clustering/dcMiniBatch.txt','w')  
bestOut = open('../ClusteringOutputs/DC_Clustering/dcBestMiniBatch.txt','w') 
file.write("n_clusters,s_score\n")
# Out:
# 19

# %%
dfLabels = dcTrain['Protein'].tolist()

# %%
max_silhouette=0
nClusters=2
t0 = time.time()

for n in lstn_clusters:
    mbk=MiniBatchKMeans(init='k-means++', n_clusters=n
                        , max_no_improvement=10, verbose=0)
    mbk.fit(dcTrain[dcTrain.columns[1:]])
    labels = mbk.labels_
    s_score = silhouette_score(dcTrain[dcTrain.columns[1:]], labels, metric='euclidean')
    dfLabels['NClusters'+str(n)] = n
    dfLabels['Labels_'+str(n)] =labels
    file.write(str(n)+",")
    file.write(str(s_score)+"\n")
    if s_score>max_silhouette:
        max_silhouette = s_score
        nClusters=n
t_mini_batch = time.time() - t0    
#print("Num clusters " + str(n))
bestOut.write("Num clusters " + str(n))
#print("Silhouette score " + str(max_silhouette))
bestOut.write("Silhouette score " + str(max_silhouette))
#print("Running time " + str(t_mini_batch))
file.close()
bestOut.close()

# %%
dfLabels.head()
# Out:
#    NClusters2  Labels_2  NClusters3  Labels_3  NClusters4  Labels_4  \
# 0         NaN         0           3         2           4         0
# 1         NaN         0           3         2           4         0
# 2         NaN         0           3         1           4         0
# 3         NaN         0           3         2           4         0
# 4         NaN         0           3         2           4         0
#
#    NClusters5  Labels_5  NClusters6  Labels_6    ...      NClusters25  \
# 0           5         4           6         0    ...               25
# 1           5         4           6         0    ...               25
# 2           5         0           6         1    ...               25
# 3           5         4           6         0    ...               25
# 4           5         4           6         0    ...               25
#
#    Labels_25  NClusters26  Labels_26  NClusters27  Labels_27  NClusters28  \
# 0         11           26         12           27          0           28
# 1         12           26          7           27          3           28
# 2         11           26          0           27         15           28
# 3         12           26          7           27          3           28
# 4         12           26          7           27          3           28
#
#    Labels_28  NClusters29  Labels_29
# 0         20           29         12
# 1         23           29         17
# 2          2           29         21
# 3         23           29         17
# 4         23           29         12
#
# [5 rows x 56 columns]

# %%
dfLabels['NClusters2'] =2

# %%
dfLabels.describe()
# Out:
#        NClusters2      Labels_2  NClusters3      Labels_3  NClusters4  \
# count     15998.0  15998.000000     15998.0  15998.000000     15998.0
# mean          2.0      0.154519         3.0      1.658832         4.0
# std           0.0      0.361457         0.0      0.621443         0.0
# min           2.0      0.000000         3.0      0.000000         4.0
# 25%           2.0      0.000000         3.0      1.000000         4.0
# 50%           2.0      0.000000         3.0      2.000000         4.0
# 75%           2.0      0.000000         3.0      2.000000         4.0
# max           2.0      1.000000         3.0      2.000000         4.0
#
#            Labels_4  NClusters5      Labels_5  NClusters6      Labels_6  \
# count  15998.000000     15998.0  15998.000000     15998.0  15998.000000
# mean       0.291974         5.0      3.131079         6.0      1.128641
# std        0.632969         0.0      1.393600         0.0      1.732705
# min        0.000000         5.0      0.000000         6.0      0.000000
# 25%        0.000000         5.0      3.000000         6.0      0.000000
# 50%        0.000000         5.0      4.000000         6.0      0.000000
# 75%        0.000000         5.0      4.000000         6.0      1.000000
# max        3.000000         5.0      4.000000         6.0      5.000000
#
#            ...       NClusters25     Labels_25  NClusters26     Labels_26  \
# count      ...           15998.0  15998.000000      15998.0  15998.000000
# mean       ...              25.0     11.751531         26.0     10.434429
# std        ...               0.0      5.916303          0.0      7.281929
# min        ...              25.0      0.000000         26.0      0.000000
# 25%        ...              25.0     10.000000         26.0      6.000000
# 50%        ...              25.0     12.000000         26.0      7.000000
# 75%        ...              25.0     15.000000         26.0     15.000000
# max        ...              25.0     24.000000         26.0     25.000000
#
#        NClusters27     Labels_27  NClusters28     Labels_28  NClusters29  \
# count      15998.0  15998.000000      15998.0  15998.000000      15998.0
# mean          27.0     10.798975         28.0     14.609826         29.0
# std            0.0      7.734383          0.0      9.425832          0.0
# min           27.0      0.000000         28.0      0.000000         29.0
# 25%           27.0      3.000000         28.0      6.000000         29.0
# 50%           27.0     11.000000         28.0     17.000000         29.0
# 75%           27.0     17.000000         28.0     23.000000         29.0
# max           27.0     26.000000         28.0     27.000000         29.0
#
#           Labels_29
# count  15998.000000
# mean      14.282598
# std        8.197740
# min        0.000000
# 25%        8.000000
# 50%       17.000000
# 75%       19.000000
# max       28.000000
#
# [8 rows x 56 columns]

# %% [markdown]
# dfLabels.insert(0,column='Protein',value  = dcTrain['Protein'].tolist())

# %%
dfLabels.head()
# Out:
#   Protein  NClusters2  Labels_2  NClusters3  Labels_3  NClusters4  Labels_4  \
# 0    LEF1           2         0           3         2           4         0
# 1    LEF1           2         0           3         2           4         0
# 2    LEF1           2         0           3         1           4         0
# 3    LEF1           2         0           3         2           4         0
# 4    LEF1           2         0           3         2           4         0
#
#    NClusters5  Labels_5  NClusters6    ...      NClusters25  Labels_25  \
# 0           5         4           6    ...               25         11
# 1           5         4           6    ...               25         12
# 2           5         0           6    ...               25         11
# 3           5         4           6    ...               25         12
# 4           5         4           6    ...               25         12
#
#    NClusters26  Labels_26  NClusters27  Labels_27  NClusters28  Labels_28  \
# 0           26         12           27          0           28         20
# 1           26          7           27          3           28         23
# 2           26          0           27         15           28          2
# 3           26          7           27          3           28         23
# 4           26          7           27          3           28         23
#
#    NClusters29  Labels_29
# 0           29         12
# 1           29         17
# 2           29         21
# 3           29         17
# 4           29         12
#
# [5 rows x 57 columns]

# %%
dfLabels.to_csv('../ClusteringOutputs/DC_Clustering/DCLabelsKmeans.csv')
