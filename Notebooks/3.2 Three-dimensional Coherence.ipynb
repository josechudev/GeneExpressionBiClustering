# %% [markdown]
# # Tridimensional Coherence

# %%
# %%latex
# Define H for a tridimensional space given two trajectories x and y in J temporary points.
# $$
# H_{+}(x,y,J) = 1 - \frac{1}{|J|} \cdot \sum \limits_{i \in J } \frac {(d(x_{j},\bar{x}) - d(y_{j},\bar{y}))^2}{2}
# $$
# Out:
# Define H for a tridimensional space given two trajectories x and y in J temporary points.
# $$
# H_{+}(x,y,J) = 1 - \frac{1}{|J|} \cdot \sum \limits_{i \in J } \frac {(d(x_{j},\bar{x}) - d(y_{j},\bar{y}))^2}{2}
# $$

# %%
# %%latex
# Define H for a new term 'z' in X
# $$
# H_{1}(I,J,X,z) =H_{0}(I,J,X) \cdot \frac{(I-1)}{(I+1)} + \frac{|2|}{(I)(I+1)} \cdot \sum_{x \epsilon X} {h(x,z,J)}
# $$
# Out:
# Define H for a new term 'z' in X
# $$
# H_{1}(I,J,X,z) =H_{0}(I,J,X) \cdot \frac{(I-1)}{(I+1)} + \frac{|2|}{(I)(I+1)} \cdot \sum_{x \epsilon X} {h(x,z,J)}
# $$

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D

# %%
points = np.array([[0.0,0.0,0],[0.5,0.5,0.2],[0.25,0.25,0.4],[0.0,0.0,0.6],[-0.25,-0.25,0.8],[-0.5,-0.5,1]])

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.plot(points[0], points[1], points[2], points[3], points[4], marker = 'x')
plt.show()

# %%
points = np.array([[ 0.86063431,  0.07119279,  1.70377142],
                   [ 0.86391084,  0.07014899,  1.72184785],
                   [ 0.86332177,  0.069444  ,  1.71182579],
                   [ 0.86192988,  0.06913941,  1.69818289],
                   [ 0.86166436,  0.06916367,  1.69527615]]).T

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.plot(points[0], points[1], points[2], marker = 'x')
ax.scatter(*points.T[0], color = 'red')
plt.show()
