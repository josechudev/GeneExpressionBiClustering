# %%
# %matplotlib inline
import gc
import pandas as pd
import glob
import sklearn
import numpy as np
import matplotlib
matplotlib.use('Agg')
# Out:
# /home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/ipykernel_launcher.py:8: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-b19852794273>", line 1, in <module>
#     get_ipython().run_line_magic('matplotlib', 'inline')
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2095, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-107>", line 2, in matplotlib
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/IPython/core/magics/pylab.py", line 99, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2978, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 308, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/matplotlib/pyplot.py", line 229, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()

# %%
diFiles=glob.glob("../Di/*")
diFiles
# Out:
# ['../Di/Jnk.csv',
#  '../Di/IRF4.csv',
#  '../Di/LEF1.csv',
#  '../Di/Ikk2.csv',
#  '../Di/CTNNB1.csv',
#  '../Di/Erk.csv',
#  '../Di/MYC.csv']

# %%
trainIndexFiles=glob.glob("../Train/*")
frames = list()
for f in trainIndexFiles:
    indices = pd.read_csv(f,sep=";")
    indexList=list(indices['0'])
    protein = f.split("/")[-1].split(".")[0]
    fpath = '../Dc/'+f.split("/")[-1].split(".")[0]+".csv"
    diRead = pd.read_csv(fpath,sep=";")
    diPartialTrain=diRead[diRead.columns[5:]].loc[indexList].copy()
    diPartialTrain.insert(0,column='Protein',value =protein )
    del diRead
    gc.collect()
    frames.append(diPartialTrain)

# %%
diTrain = pd.concat(frames)

# %%
diTrain.to_csv("../FullTrain/FullTrainDI/FullTrainDI.csv")

# %%
diTrain.head()
# Out:
#      Protein  X0min_neg_effect-X0min_neg_cause  X15min_effect-X0min_neg_cause  \
# 1530    LEF1                          1.023241                       0.724441
# 1531    LEF1                          0.169366                       0.093080
# 1532    LEF1                          1.887236                       0.981507
# 1533    LEF1                          0.237701                      -0.071842
# 1535    LEF1                          0.757642                       0.409183
#
#       X15min_effect-X15min_cause  X30min_effect-X0min_neg_cause  \
# 1530                    0.818558                       0.563618
# 1531                    0.621927                       0.102329
# 1532                    2.324589                       0.764263
# 1533                    0.166615                       0.123891
# 1535                    0.489564                      -0.257325
#
#       X30min_effect-X15min_cause  X30min_effect-X30min_cause  \
# 1530                    0.484836                    0.672051
# 1531                    0.108679                    0.166695
# 1532                    0.324520                    1.247644
# 1533                   -0.070192                    0.429748
# 1535                   -0.228940                    0.444693
#
#       X90min_effect-X0min_neg_cause  X90min_effect-X15min_cause  \
# 1530                      -0.033114                   -0.013766
# 1531                       0.022466                    0.021222
# 1532                      -0.241862                   -0.431564
# 1533                      -0.033902                    0.010897
# 1535                       0.024037                    0.013811
#
#       X90min_effect-X30min_cause              ...               \
# 1530                    0.068516              ...
# 1531                    0.052001              ...
# 1532                   -0.149245              ...
# 1533                   -0.006371              ...
# 1535                    0.029758              ...
#
#       X240min_effect-X240min_cause  X360min_effect-X0min_neg_cause  \
# 1530                      1.759207                        0.168689
# 1531                      0.422824                       -0.093931
# 1532                      0.462031                        0.728134
# 1533                      0.559448                       -0.021912
# 1535                      1.067780                        0.156884
#
#       X360min_effect-X15min_cause  X360min_effect-X30min_cause  \
# 1530                     0.138546                     0.072377
# 1531                     0.017554                    -0.044028
# 1532                     0.877128                     0.352315
# 1533                     0.067405                    -0.021690
# 1535                     0.128128                    -0.064193
#
#       X360min_effect-X90min_cause  X360min_effect-X120min_cause  \
# 1530                    -0.208468                      0.002047
# 1531                    -0.024721                     -0.009345
# 1532                    -0.127248                     -0.097222
# 1533                     0.000144                      0.007487
# 1535                     0.042174                      0.131908
#
#       X360min_effect-X180min_cause  X360min_effect-X210min_cause  \
# 1530                     -0.033598                      0.196686
# 1531                      0.050461                     -0.073455
# 1532                     -0.054824                      0.538076
# 1533                      0.128203                     -0.146404
# 1535                      0.014193                      0.045039
#
#       X360min_effect-X240min_cause  X360min_effect-X360min_cause
# 1530                     -0.146813                      0.336667
# 1531                     -0.042127                      0.806875
# 1532                      0.111132                      1.637100
# 1533                      0.111754                      0.439802
# 1535                      0.037291                      0.423915
#
# [5 rows x 46 columns]

# %%
lstn_clusters=range(2,30)

# %%
import time
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score

# %%
file = open('../ClusteringOutputs/DI_Clustering/diMiniBatch.txt','w')  
bestOut = open('../ClusteringOutputs/DI_Clustering/diBestMiniBatch.txt','w') 
file.write("n_clusters,s_score\n")
# Out:
# 19

# %%
dfLabels=pd.DataFrame()

# %%
dfLabels['Protein'] = diTrain['Protein'].tolist()

# %%
max_silhouette=0
nClusters=2

for n in lstn_clusters:
    mbk=MiniBatchKMeans(init='k-means++', n_clusters=n
                        , max_no_improvement=10, verbose=0)
    mbk.fit(diTrain[diTrain.columns[1:]])
    labels = mbk.labels_
    s_score = silhouette_score(diTrain[diTrain.columns[1:]], labels, metric='euclidean')
    dfLabels['NClusters'+str(n)] = n
    dfLabels['Labels_'+str(n)] =labels
    file.write(str(n)+",")
    file.write(str(s_score)+"\n")
    if s_score>max_silhouette:
        max_silhouette = s_score
        nClusters=n
#t_mini_batch = time.time() - t0    
#print("Num clusters " + str(n))
bestOut.write("Num clusters " + str(n))
#print("Silhouette score " + str(max_silhouette))
bestOut.write("Silhouette score " + str(max_silhouette))
#print("Running time " + str(t_mini_batch))
file.close()
bestOut.close()
file.close()
bestOut.close()

# %%
type(dfLabels)
# Out:
# list

# %%
dfLabels.head()
# Out:
#   Protein  NClusters2  Labels_2  NClusters3  Labels_3  NClusters4  Labels_4  \
# 0    LEF1           2         0           3         0           4         1
# 1    LEF1           2         0           3         0           4         1
# 2    LEF1           2         0           3         0           4         3
# 3    LEF1           2         0           3         0           4         1
# 4    LEF1           2         0           3         0           4         1
#
#    NClusters5  Labels_5  NClusters6    ...      NClusters25  Labels_25  \
# 0           5         0           6    ...               25          9
# 1           5         0           6    ...               25          5
# 2           5         0           6    ...               25          0
# 3           5         0           6    ...               25          5
# 4           5         0           6    ...               25          5
#
#    NClusters26  Labels_26  NClusters27  Labels_27  NClusters28  Labels_28  \
# 0           26         13           27         18           28         15
# 1           26          0           27         15           28          2
# 2           26         13           27         23           28          1
# 3           26          0           27         15           28          2
# 4           26          0           27         15           28          2
#
#    NClusters29  Labels_29
# 0           29          1
# 1           29         21
# 2           29          9
# 3           29         21
# 4           29         21
#
# [5 rows x 57 columns]

# %%
dfLabels.to_csv('../ClusteringOutputs/DI_Clustering/DILabelsKmeans.csv')

# %%
mbk=MiniBatchKMeans(init='k-means++', n_clusters=5
                        , max_no_improvement=10, verbose=0)
mbk.fit(diTrain[diTrain.columns[1:]])
labels = mbk.labels_
s_score = silhouette_score(diTrain[diTrain.columns[1:]], labels, metric='euclidean')

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3, svd_solver='full')

# %%
pca.fit(diTrain[diTrain.columns[1:]])
# Out:
# PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#   svd_solver='full', tol=0.0, whiten=False)

# %%
pca_3d = pca.transform(diTrain[diTrain.columns[1:]]).T

# %%
len(pca_3d)
# Out:
# 3

# %%
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

# %%
x=pca_3d[0]
y=pca_3d[1]
z=pca_3d[2]

# %%
fig = pyplot.figure()
ax = Axes3D(fig)
ax.scatter(x, y, z,c=labels)
pyplot.show()

# %%
import matplotlib
matplotlib.use('Agg')
# Out:
# /home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'TkAgg' by the following code:
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2856, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-22-4ea51f371400>", line 1, in <module>
#     get_ipython().run_line_magic('pylab', '')
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2095, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-108>", line 2, in pylab
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/IPython/core/magics/pylab.py", line 155, in pylab
#     gui, backend, clobbered = self.shell.enable_pylab(args.gui, import_all=import_all)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3017, in enable_pylab
#     gui, backend = self.enable_matplotlib(gui)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2978, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 308, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/matplotlib/pyplot.py", line 229, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/matplotlib/__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
