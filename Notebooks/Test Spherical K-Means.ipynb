# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import spherecluster

import numpy as np

import logging
from sklearn.cluster import KMeans

from spherecluster import SphericalKMeans
from spherecluster import VonMisesFisherMixture

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install spherecluster

# %%
data = pd.read_csv("TestData/SimulatedDataCoherence/BiclusterA_high.csv")

# %%
skm = SphericalKMeans(n_clusters=5, init='k-means++')

# %%
skm.fit(data)
# Out:
# SphericalKMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=5,
#         n_init=10, n_jobs=1, normalize=True, random_state=None, tol=0.0001,
#         verbose=0)

# %%
skm.labels_
# Out:
# array([0, 2, 4, 3, 2, 3, 2, 4, 4, 2, 0, 4, 2, 4, 4, 2, 1, 2, 3, 0, 2, 0, 0,
#        0, 2, 3, 3, 2, 2, 4, 1, 2, 4, 2, 4, 2, 4, 2, 3, 0, 0, 1, 3, 2, 2, 0,
#        2, 1, 3, 3, 0, 0, 0, 3, 4, 2, 0, 4, 1, 1, 2, 2, 3, 3, 2, 3, 4, 1, 1,
#        3, 4, 1, 2, 0, 2, 1, 1, 3, 3, 4, 1, 0, 1, 4, 4, 0, 4, 1, 2, 2, 2, 4,
#        0, 4, 1, 0, 4, 3, 4], dtype=int32)

# %%
sns.kdeplot(data= np.array(data)[np.where(skm.labels_ == 0)[0]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-f5ba6cd9c903> in <module>()
# ----> 1 sns.kdeplot(data= np.array(data)[np.where(skm.labels_ == 0)[0]])
#
# ~/anaconda3/envs/Biclustering/lib/python3.6/site-packages/seaborn/distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     628         warn = True
#     629         bivariate = True
# --> 630         x, y = data.T
#     631     elif isinstance(data, pd.DataFrame) and np.ndim(data) > 1:
#     632         warn = True
#
# ValueError: too many values to unpack (expected 2)

# %%
data['labales'] = skm.labels_
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-6f60097fbf34> in <module>()
# ----> 1 df = pd.DataFrame({np.array(data),skm.labels_})
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
hour, direction = np.meshgrid(np.arange(24), np.arange(1,3))
df = pd.DataFrame({"hour": hour.flatten(), "direction": direction.flatten()})
df["hourly_avg_count"] = np.random.randint(14,30, size=len(df))

plt.figure(figsize=(12,8))
sns.tsplot(df, time='hour', unit = "direction", 
               condition='direction', value='hourly_avg_count')

plt.show()
# Out:
# /home/a20125359/anaconda3/envs/Biclustering/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
